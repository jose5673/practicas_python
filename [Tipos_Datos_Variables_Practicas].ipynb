# %% [markdown]
# # 💪 PRÁCTICAS: TIPOS DE DATOS Y VARIABLES
#
# ## 🎯 **Objetivo de las Prácticas**
#
# Este notebook contiene **ejercicios graduales** para consolidar tu comprensión de tipos de datos y variables. Cada ejercicio está diseñado para prepararte para las aplicaciones industriales que desarrollarás con PyModbus, Flask y SQL.
#
# ### 📋 **Estructura de las Prácticas:**
#
# 1. **🟢 Nivel 1 (Básico):** Verificar comprensión conceptual
# 2. **🟡 Nivel 2 (Intermedio):** Combinar conceptos aprendidos
# 3. **🟠 Nivel 3 (Avanzado):** Pensamiento creativo y estructuración
# 4. **🔴 Nivel 4 (Proyecto):** Aplicación significativa del concepto
#
# ### 🎯 **Metodología de Práctica:**
#
# 1. **Lee el ejercicio** completamente antes de empezar
# 2. **Escribe tu solución** en la celda correspondiente
# 3. **Ejecuta y verifica** que funcione correctamente
# 4. **Compara** con la solución proporcionada
# 5. **Analiza diferencias** y optimizaciones posibles
#
# ---
#
# ## 📊 **¿Por qué estos ejercicios te preparan para tus metas finales?**
#
# - 🏭 **PyModbus:** Manejarás identificadores de dispositivos, valores de registros, direcciones IP
# - 🌐 **Flask:** Procesarás datos JSON, crearás endpoints, manejarás parámetros de URL
# - 💾 **SQL:** Almacenarás diferentes tipos de datos, crearás consultas con strings
# - 🖥️ **Tkinter:** Mostrarás información formateada, validarás entradas de usuario
# - 📊 **NumPy/Matplotlib:** Convertirás datos, formatearás etiquetas, calcularás estadísticas
#
# **¡Cada ejercicio es un paso hacia tu maestría en Python industrial!** 🚀

# %% [markdown]
# # 🟢 NIVEL 1: EJERCICIOS BÁSICOS
#
# ## 📝 **Ejercicio 1.1: Crear Variables de Sistema Industrial**
#
# **Objetivo:** Crear variables para representar el estado de un sistema de control.
#
# **Instrucciones:**
# 1. Crea variables para almacenar la siguiente información:
#    - Nombre de la planta: "Planta Química Norte"
#    - Número de reactores: 3
#    - Temperatura actual: 68.5°C
#    - Sistema en operación: True
#    - Presión máxima permitida: 4.2 bar
#
# 2. Muestra cada variable con su tipo de dato usando `type()`
# 3. Crea un reporte formateado con f-strings

# %%
# 🧑‍💻 TU SOLUCIÓN - Ejercicio 1.1
# Escribe tu código aquí:

# 1. Crear las variables solicitadas


# 2. Mostrar cada variable con su tipo


# 3. Crear reporte formateado

# %%
# ✅ SOLUCIÓN MODELO - Ejercicio 1.1

# 1. Crear las variables solicitadas
nombre_planta = "Planta Química Norte"
numero_reactores = 3
temperatura_actual = 68.5
sistema_operativo = True
presion_maxima = 4.2

# 2. Mostrar cada variable con su tipo
print("🔍 VARIABLES Y SUS TIPOS:")
print(f"nombre_planta = '{nombre_planta}' → {type(nombre_planta)}")
print(f"numero_reactores = {numero_reactores} → {type(numero_reactores)}")
print(f"temperatura_actual = {temperatura_actual} → {type(temperatura_actual)}")
print(f"sistema_operativo = {sistema_operativo} → {type(sistema_operativo)}")
print(f"presion_maxima = {presion_maxima} → {type(presion_maxima)}")

# 3. Crear reporte formateado
print(f"\n📊 REPORTE DEL SISTEMA:")
print(f"{'='*50}")
print(f"Planta: {nombre_planta}")
print(f"Reactores instalados: {numero_reactores}")
print(f"Temperatura actual: {temperatura_actual}°C")
print(f"Sistema operativo: {'SÍ' if sistema_operativo else 'NO'}")
print(f"Presión máxima: {presion_maxima} bar")
print(f"{'='*50}")

# 🎯 ANÁLISIS DE LA SOLUCIÓN:
print(f"\n🎯 PUNTOS CLAVE DE ESTA SOLUCIÓN:")
print("✅ Variables con nombres descriptivos (snake_case)")
print("✅ Tipos de datos apropiados para cada información")
print("✅ Uso de f-strings para formateo profesional")
print("✅ Conversión de booleano a texto legible")
print("✅ Reporte visualmente organizado")

# %% [markdown]
# # 🟡 NIVEL 2: EJERCICIOS INTERMEDIOS
#
# ## 🧮 **Ejercicio 2.1: Calculadora de Eficiencia Energética**
#
# **Objetivo:** Combinar tipos numéricos, strings y booleanos para calcular eficiencia de un sistema.
#
# **Escenario:** Eres el ingeniero a cargo de un sistema de calentamiento industrial. Necesitas calcular la eficiencia energética y generar reportes automáticos.
#
# **Datos del sistema:**
# - Potencia nominal: 5000 W
# - Voltaje de operación: 380 V
# - Tiempo de operación: 8.5 horas
# - Temperatura inicial: 18.3°C
# - Temperatura final: 85.7°C
# - Costo energía: $0.12 por kWh
#
# **Tareas:**
# 1. Calcula la corriente consumida (I = P/V)
# 2. Calcula la energía total consumida en kWh
# 3. Calcula el costo total de operación
# 4. Calcula el incremento de temperatura
# 5. Determina si el sistema es eficiente (más de 8°C por kWh)
# 6. Genera un reporte profesional con toda la información

# %% [markdown]
# # 🔴 NIVEL 4: PROYECTO INTEGRADOR
#
# ## 🏭 **Proyecto: Sistema de Monitoreo Industrial Básico**
#
# **Objetivo:** Crear un sistema completo que simule el monitoreo de una planta industrial, integrando todos los tipos de datos y conceptos aprendidos.
#
# **Escenario:** Desarrollas el módulo de diagnóstico para una planta química que tiene 3 reactores. Cada reactor tiene sensores de temperatura, presión y nivel. Tu sistema debe procesar datos y generar reportes de estado.
#
# ### 📋 **Especificaciones del Proyecto:**
#
# **Reactor 1 - "Reactor Principal"**
# - ID: 101
# - Temperatura: 78.5°C (límite: 85°C)
# - Presión: 2.3 bar (límite: 3.0 bar)
# - Nivel: 67% (mínimo: 20%)
# - Estado: Operativo
#
# **Reactor 2 - "Reactor Secundario"**
# - ID: 102
# - Temperatura: 91.2°C (límite: 85°C) ⚠️
# - Presión: 1.8 bar (límite: 3.0 bar)
# - Nivel: 15% (mínimo: 20%) ⚠️
# - Estado: Advertencia
#
# **Reactor 3 - "Reactor de Respaldo"**
# - ID: 103
# - Temperatura: 45.0°C (límite: 85°C)
# - Presión: 1.2 bar (límite: 3.0 bar)
# - Nivel: 89% (mínimo: 20%)
# - Estado: Standby
#
# ### 🎯 **Funcionalidades a Implementar:**
#
# 1. **Variables del Sistema:**
#    - Crear variables para cada reactor con todos sus parámetros
#    - Definir constantes para los límites de seguridad
#    - Variables para información de la planta
#
# 2. **Cálculos de Estado:**
#    - Determinar si cada parámetro está dentro de límites
#    - Calcular el estado general de cada reactor
#    - Contar reactores operativos, en advertencia y en standby
#
# 3. **Reporte Ejecutivo:**
#    - Resumen general de la planta
#    - Estado detallado de cada reactor
#    - Recomendaciones basadas en el análisis
#    - Cálculo de eficiencia operacional
#
# 4. **Sistema de Alertas:**
#    - Identificar parámetros fuera de rango
#    - Generar mensajes de alerta específicos
#    - Priorizar alertas por nivel de riesgo
#
# **¡Este proyecto simula un caso real de lo que desarrollarás con PyModbus y Flask!** 🚀
